# %%
pip install psycopg2 pandas sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'global AP dataset.csv')

# %%
df
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'City', 'AQI Value', 'AQI Category', 'CO AQI Value',
#        'CO AQI Category', 'Ozone AQI Value', 'Ozone AQI Category',
#        'NO2 AQI Value', 'NO2 AQI Category', 'PM2.5 AQI Value',
#        'PM2.5 AQI Category'],
#       dtype='object')

# %%
# !pip install pycountry

# %%
# !pip install pycountry
import pycountry #importing pycountry

# Function to get the three-letter ISO alpha-3 code for a country name
def get_country_code(country_name):
    try:
        return pycountry.countries.lookup(country_name).alpha_3
    except LookupError:
        return None  # If the country is not found

# Load the DataFrame and assign it to global_ap_df
global_ap_df = pd.read_csv(r'global AP dataset.csv')

# Apply the function to the column containing country names
# Replace 'Country' with the actual column name in your dataset
global_ap_df['Country_Code'] = global_ap_df['Country'].apply(get_country_code)

# Display the first few rows to check the results
global_ap_df[['Country', 'Country_Code']]
# Out:
# ...
#                         Country Country_Code
# 0            Russian Federation          RUS
# 1                        Brazil          BRA
# 2                         Italy          ITA
# 3                        Poland          POL
# 4                        France          FRA
# ...                         ...          ...
# 23458                     India          IND
# 23459                    France          FRA
# 23460                     India          IND
# 23461  United States of America          USA
# 23462                  Malaysia          MYS
#
# [23463 rows x 2 columns]

# %%
global_ap_df
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
global_ap_df.drop(['City'],axis=1, inplace = True)

# %%
global_ap_df
# Out:
#                         Country  AQI Value AQI Category  CO AQI Value  \
# 0            Russian Federation         51     Moderate             1
# 1                        Brazil         41         Good             1
# 2                         Italy         66     Moderate             1
# 3                        Poland         34         Good             1
# 4                        France         22         Good             0
# ...                         ...        ...          ...           ...
# 23458                     India        184    Unhealthy             3
# 23459                    France         50         Good             1
# 23460                     India         50         Good             1
# 23461  United States of America         71     Moderate             1
# 23462                  Malaysia         70     Moderate             1
#
#       CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# ...

# %%
global_ap_df.columns
# Out:
# Index(['Country', 'AQI Value', 'AQI Category', 'CO AQI Value',
#        'CO AQI Category', 'Ozone AQI Value', 'Ozone AQI Category',
#        'NO2 AQI Value', 'NO2 AQI Category', 'PM2.5 AQI Value',
#        'PM2.5 AQI Category', 'Country_Code'],
#       dtype='object')

# %%
global_ap_df.sort_values(by=['Country'], ascending=True, inplace=True)
global_ap_df.head()
# Out:
#            Country  AQI Value AQI Category  CO AQI Value CO AQI Category  \
# 14768  Afghanistan        198    Unhealthy             1            Good
# 17330  Afghanistan         68     Moderate             0            Good
# 6520   Afghanistan         84     Moderate             1            Good
# 8422   Afghanistan         72     Moderate             0            Good
# 22237  Afghanistan         83     Moderate             0            Good
#
#        Ozone AQI Value Ozone AQI Category  NO2 AQI Value NO2 AQI Category  \
# 14768               35               Good              0             Good
# 17330               32               Good              0             Good
# 6520                64           Moderate              0             Good
# 8422                48               Good              0             Good
# 22237               40               Good              0             Good
#
#        PM2.5 AQI Value PM2.5 AQI Category Country_Code
# ...

# %%
global_ap_df.describe()
# Out:
#           AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# count  23463.000000  23463.000000     23463.000000   23463.000000
# mean      72.010868      1.368367        35.193709       3.063334
# std       56.055220      1.832064        28.098723       5.254108
# min        6.000000      0.000000         0.000000       0.000000
# 25%       39.000000      1.000000        21.000000       0.000000
# 50%       55.000000      1.000000        31.000000       1.000000
# 75%       79.000000      1.000000        40.000000       4.000000
# max      500.000000    133.000000       235.000000      91.000000
#
#        PM2.5 AQI Value
# count     23463.000000
# mean         68.519755
# std          54.796443
# min           0.000000
# 25%          35.000000
# 50%          54.000000
# 75%          79.000000
# max         500.000000

# %%
global_ap_df.dropna()
# Out:
#            Country  AQI Value AQI Category  CO AQI Value CO AQI Category  \
# 14768  Afghanistan        198    Unhealthy             1            Good
# 17330  Afghanistan         68     Moderate             0            Good
# 6520   Afghanistan         84     Moderate             1            Good
# 8422   Afghanistan         72     Moderate             0            Good
# 22237  Afghanistan         83     Moderate             0            Good
# ...            ...        ...          ...           ...             ...
# 17387     Zimbabwe         37         Good             1            Good
# 17030     Zimbabwe         25         Good             0            Good
# 23058     Zimbabwe         52     Moderate             2            Good
# 22950     Zimbabwe         65     Moderate             1            Good
# 17817     Zimbabwe         42         Good             1            Good
#
#        Ozone AQI Value Ozone AQI Category  NO2 AQI Value NO2 AQI Category  \
# ...

# %%
global_ap_df.isna().sum()
# Out:
# Country                427
# AQI Value                0
# AQI Category             0
# CO AQI Value             0
# CO AQI Category          0
# Ozone AQI Value          0
# Ozone AQI Category       0
# NO2 AQI Value            0
# NO2 AQI Category         0
# PM2.5 AQI Value          0
# PM2.5 AQI Category       0
# Country_Code          1042
# dtype: int64

# %%
global_ap_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23463 entries, 14768 to 23420
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             23036 non-null  object
#  1   AQI Value           23463 non-null  int64
#  2   AQI Category        23463 non-null  object
#  3   CO AQI Value        23463 non-null  int64
#  4   CO AQI Category     23463 non-null  object
#  5   Ozone AQI Value     23463 non-null  int64
#  6   Ozone AQI Category  23463 non-null  object
#  7   NO2 AQI Value       23463 non-null  int64
#  8   NO2 AQI Category    23463 non-null  object
#  9   PM2.5 AQI Value     23463 non-null  int64
#  10  PM2.5 AQI Category  23463 non-null  object
#  11  Country_Code        22421 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.3+ MB

# %%
visual = global_ap_df.select_dtypes(include='int64')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.histplot(visual['AQI Value'], kde=True, bins=30, color='blue')
plt.title('Distribution of Overall AQI Values', fontsize=16)
plt.xlabel('AQI Value', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(visual, orient="h", palette="Set2")
plt.title('Boxplot of AQI Metrics', fontsize=16)
plt.xlabel('AQI Value', fontsize=12)
plt.ylabel('Metrics', fontsize=12)
plt.show()

# %%
# 2. Correlation heatmap
plt.figure(figsize=(8, 6))
correlation_matrix = visual.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %%
import pandas as pd
from sqlalchemy import create_engine
 # Create connection to PostgreSQL
# Replace with your PostgreSQL credentials
DATABASE_URI = 'postgresql+psycopg2://postgres:Admin@localhost:5432/Test'
engine = create_engine(DATABASE_URI)
 
# Write DataFrame to PostgreSQL
table_name = 'Aqi'
 
try:
    global_ap_df.to_sql(table_name, con=engine, if_exists='replace', index=False)  # Use 'append' to add to an existing table
    print(f"DataFrame successfully stored in table '{table_name}'")
except Exception as e:
    print(f"Error: {e}")
# Out:
# DataFrame successfully stored in table 'Aqi'
